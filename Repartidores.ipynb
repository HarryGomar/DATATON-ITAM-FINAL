# %%
import pandas as pd

df1 = pd.read_csv('/content/drive/MyDrive/Dataton/Dataton final/ENOE/ENOE_COE1T224.csv')
df2 = pd.read_csv('/content/drive/MyDrive/Dataton/Dataton final/ENOE/ENOE_COE2T224.csv')

# %%
combined_df = pd.concat([df1, df2], ignore_index=True)

# %%
for col in combined_df.columns:
  print(col)
# Out:
# r_def
# cd_a
# ent
# con
# upm
# d_sem
# n_pro_viv
# v_sel
# n_hog
# h_mud
# n_ent
# per
# n_ren
# eda
# n_inf
# p1
# p1a1
# p1a2
# p1a3
# p1b
# p1c
# p1d
# p1e
# p2_1
# p2_2
# p2_3
# p2_4
# p2_9
# p2a_dia
# p2a_sem
# p2a_mes
# p2a_anio
# p2b_dia
# p2b_sem
# p2b_mes
# p2b_anio
# p2b
# p2c
# p2d1
# p2d2
# p2d3
# p2d4
# p2d5
# p2d6
# p2d7
# p2d8
# p2d9
# p2d10
# p2d11
# p2d99
# p2e
# p2f
# p2g1
# p2g2
# p2h1
# p2h2
# p2h3
# p2h4
# p2h9
# p2i
# p2j
# p2k_anio
# p2k_mes
# p2k
# p3
# p3a
# p3b
# p3c1
# p3c2
# p3c3
# p3c4
# p3c9
# p3d
# p3e
# p3f1
# p3f2
# p3g1_1
# p3g1_2
# p3g2_1
# p3g2_2
# p3g3_1
# p3g3_2
# p3g4_1
# p3g4_2
# p3g9
# p3g_tot
# p3h
# p3i
# p3j1
# p3j2
# p3k1
# p3k2
# p3k3
# p3k4
# p3k5
# p3k9
# p3l
# p4
# p4_1
# p4_2
# p4_3
# p4a
# p4a_1
# p4b
# p4c
# p4d1
# p4d2
# p4d3
# p4e
# p4f
# p4g
# p4h
# p4i
# p4i_1
# p5
# p5a
# p5b_hlu
# p5b_mlu
# p5b_hma
# p5b_mma
# p5b_hmi
# p5b_mmi
# p5b_hju
# p5b_mju
# p5b_hvi
# p5b_mvi
# p5b_hsa
# p5b_msa
# p5b_hdo
# p5b_mdo
# p5b_thrs
# ...

# %%
unique_p3_values = combined_df['p3'].unique()
print(unique_p3_values)

#To get the number of unique values:
num_unique_p3 = len(unique_p3_values)
print(f"Number of unique values in 'p3': {num_unique_p3}")
# Out:
# ['2512' '2632' ' ' '7101' '1615' '5111' '9723' '8342' '3111' '5116' '2135'
#  '4214' '2651' '4111' '2432' '9521' '9512' '8341' '9633' '2263' '1511'
#  '3211' '3115' '4312' '9621' '8352' '5112' '4211' '7132' '9331' '4213'
#  '2122' '2121' '2271' '5313' '9601' '3122' '9321' '9661' '1226' '4222'
#  '7121' '2642' '4224' '9411' '2643' '2644' '5211' '9611' '9641' '8133'
#  '8344' '1522' '2436' '9722' '1711' '3212' '5114' '9221' '5222' '3121'
#  '2232' '8142' '2332' '2715' '3213' '2532' '5115' '2541' '2261' '9712'
#  '2633' '1712' '2252' '3131' '9231' '7221' '2331' '2321' '1412' '2422'
#  '8121' '2531' '8343' '4231' '7211' '2426' '8144' '2162' '2437' '5312'
#  '9662' '1621' '4221' '1411' '2142' '7341' '5254' '7513' '7311' '2424'
#  '2152' '1614' '2511' '2513' '2112' '3113' '2111' '2281' '2821' '2711'
#  '7515' '5241' '2822' '8212' '7214' '2543' '3132' '7134' '2653' '8153'
#  '3201' '9232' '2433' '5231' '6125' '2654' '4201' '1212' '9236' '9111'
# ...

# %%
filtered_df = combined_df[combined_df['p3'].astype(str).str.contains('971|972')]
filtered_df[['eda']]
# Out:
#         eda
# 6        19
# 73       17
# 144      51
# 229      43
# 280      59
# ...     ...
# 346906   59
# 346986   57
# 348178   25
# 348342   12
# 348713   47
#
# [913 rows x 1 columns]

# %%
unique_combinations = filtered_df[['cd_a', 'ent']].drop_duplicates()
unique_combinations
# Out:
#         cd_a  ent
# 6          1    9
# 4093       1   15
# 7836       2   14
# 11332      3   19
# 15063      4   21
# ...      ...  ...
# 338401    83   12
# 340610    84   14
# 343229    85   21
# 348178    86   22
# 348342    86   23
#
# [159 rows x 2 columns]
